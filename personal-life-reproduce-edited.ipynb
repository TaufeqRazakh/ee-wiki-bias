# %% [markdown]
# ### this script is to extract events using odds ratio, do calibration based on the templates and finally plot the figures that will be needed in the paper

# %%
import pandas as pd
df_m = pd.read_csv("data/ee-fm/df_m.csv")
df_f = pd.read_csv("data/ee-fm/df_f.csv")

# %%
import itertools
import spacy
import ast 

# nlp = spacy.load('en') # JULIE edits: remove nlp and replace nlp with sp
sp = spacy.load('en_core_web_sm')
all_stopwords = sp.Defaults.stop_words

def chain(array):
    array = ast.literal_eval(array)
    return list(itertools.chain.from_iterable(array))

def events_only(array):
    events = []
    if(len(array) > 0):
        for event in array:
            trigger_word = event["triggers"][0]["text"]
            w = sp(trigger_word)
            if w[0].lemma_ not in all_stopwords:
                events.append(w[0].lemma_)
    return events

# %%
df_f
# Out:
#       Unnamed: 0  Unnamed: 0.1                  name  \
# 0              0             0     Jody Adams (chef)
# 1              1             1          Einat Admony
# 2              2             2       Karen Akunowicz
# 3              3             3       Devin Alexander
# 4              4             4            Fatima Ali
# ...          ...           ...                   ...
# 5271        5271           925         Diana Wynyard
# 5272        5272           926         Susannah York
# 5273        5273           929         Loretta Young
# 5274        5274           931       Renée Zellweger
# 5275        5275           932  Catherine Zeta-Jones
#
#                                              name_url gender  \
# 0     https://en.wikipedia.org/wiki/Jody_Adams_(chef)      F
# 1          https://en.wikipedia.org/wiki/Einat_Admony      F
# 2       https://en.wikipedia.org/wiki/Karen_Akunowicz      F
# 3       https://en.wikipedia.org/wiki/Devin_Alexander      F
# 4            https://en.wikipedia.org/wiki/Fatima_Ali      F
# ...                                               ...    ...
# 5271                              /wiki/Diana_Wynyard      F
# 5272                              /wiki/Susannah_York      F
# 5273                              /wiki/Loretta_Young      F
# 5274                       /wiki/Ren%C3%A9e_Zellweger      F
# 5275                       /wiki/Catherine_Zeta-Jones      F
#
#                                             person_info  \
# 0     [{'section': 'Career', 'info': ['In 2011, Adam...
# 1     [{'section': 'Early life', 'info': ['Admony is...
# 2               [{'section': 'References', 'info': []}]
# 3     [{'section': 'Biography', 'info': ['In 2006, s...
# 4     [{'section': 'Early life', 'info': ["Fatima Al...
# ...                                                 ...
# 5271  [{'section': 'Life and career', 'info': ['Born...
# 5272  [{'section': 'Early life', 'info': ["York was ...
# 5273  [{'section': 'Early life', 'info': ['She was b...
# 5274  [{'section': 'Early life', 'info': ['Renée Kat...
# 5275  [{'section': 'Early life and initial stage car...
#
#                                           personal_life  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 5271  [[{'event_type': 'Life:Marry', 'triggers': [{'...
# 5272  [[{'event_type': 'Life:Marry', 'triggers': [{'...
# 5273  [[{'event_type': 'Life:Marry', 'triggers': [{'...
# 5274  [[{'event_type': 'Life:Marry', 'triggers': [{'...
# 5275  [[{'event_type': '', 'triggers': [{'event_type...
#
#                                                  career occupation  \
# 0     [[{'event_type': 'Business:Start-Org', 'trigge...      chefs
# 1     [[{'event_type': 'Business:Start-Org', 'trigge...      chefs
# 2                                                    []      chefs
# 3                                                    []      chefs
# 4     [[{'event_type': '', 'triggers': [{'event_type...      chefs
# ...                                                 ...        ...
# 5271                                                 []     acting
# 5272  [[{'event_type': '', 'triggers': [{'event_type...     acting
# 5273  [[], [{'event_type': 'Life:Marry', 'triggers':...     acting
# 5274  [[{'event_type': 'Life:Die', 'triggers': [{'ev...     acting
# 5275  [[{'event_type': '', 'triggers': [{'event_type...     acting
#
#                                               pl_events  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 5271  [{'event_type': 'Life:Marry', 'triggers': [{'e...
# 5272  [{'event_type': 'Life:Marry', 'triggers': [{'e...
# 5273  [{'event_type': 'Life:Marry', 'triggers': [{'e...
# 5274  [{'event_type': 'Life:Marry', 'triggers': [{'e...
# 5275  [{'event_type': '', 'triggers': [{'event_type'...
#
#                                             pl_ev_lemma  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 5271  ['married', 'die', 'rehearse', 'replace', 'dea...
# 5272  ['married', 'divorce', 'bear', 'play', 'evoke'...
# 5273  ['married', 'marriage', 'marriage', 'married',...
# 5274  ['married', 'engage', 'obtain', 'meet', 'separ...
# 5275  ['chronicle', 'report', 'meet', 'engage', 'mar...
#
#                                           career_events  \
# 0     [{'event_type': 'Business:Start-Org', 'trigger...
# 1     [{'event_type': 'Business:Start-Org', 'trigger...
# 2                                                    []
# 3                                                    []
# 4     [{'event_type': '', 'triggers': [{'event_type'...
# ...                                                 ...
# 5271                                                 []
# 5272  [{'event_type': '', 'triggers': [{'event_type'...
# 5273  [{'event_type': 'Life:Marry', 'triggers': [{'e...
# 5274  [{'event_type': 'Life:Die', 'triggers': [{'eve...
# 5275  [{'event_type': '', 'triggers': [{'event_type'...
#
#                                         career_ev_lemma
# 0             ['open', 'open', 'provide', 'illustrate']
# 1     ['open', 'introduce', 'list', 'appear', 'retur...
# 2                                                    []
# 3                                                    []
# 4        ['continue', 'begin', 'win', 'vote', 'finish']
# ...                                                 ...
# 5271                                                 []
# 5272  ['play', 'begin', 'perform', 'agree', 'appear'...
# 5273  ['married', 'marriage', 'marry', 'annul', 'elo...
# 5274  ['kill', 'receive', 'note', 'applaud', 'play',...
# 5275  ['recount', 'receive', 'feature', 'relocate', ...
#
# [5276 rows x 13 columns]

# %%
def extract_events(df_nomi_female):
    # JULIE edits: comment out the first four lines because they are already calculated in the provided dfs
    # no need to redo 
    # saves computation power/cost 
#     df_nomi_female["pl_events"] = df_nomi_female["personal_life"].apply(ast.literal_eval)
#     df_nomi_female["pl_ev_lemma"] = df_nomi_female["pl_events"].apply(ast.literal_eval)
#     df_nomi_female["career_events"] = df_nomi_female["career"].apply(chain)
#     df_nomi_female["career_ev_lemma"] = df_nomi_female["career_events"].apply(events_only)
    df_nomi_female["career_ev_lemma"] = df_nomi_female["career_ev_lemma"].apply(ast.literal_eval)
    df_nomi_female["pl_ev_lemma"] = df_nomi_female["pl_ev_lemma"].apply(ast.literal_eval)
    df_nomi_female["pl_ev_num"] = df_nomi_female["pl_ev_lemma"].apply(len)
    df_nomi_female["cr_ev_num"] = df_nomi_female["career_ev_lemma"].apply(len)
    return df_nomi_female

# %% [markdown]
# ## odds ratio calculation function
# ### *--------------------------------------------------------*

# %%
from collections import OrderedDict
def odds_ratio(f_dict, m_dict, topk=50, threshold=2):
    very_small_value = 0.00001
    if len(f_dict.keys()) != len(m_dict.keys()):
        raise Exception("The category for analyzing the male and female should be the same!")
    else:
        odds_ratio = {}
        total_num_f = sum(f_dict.values())
        total_num_m = sum(m_dict.values())
        for key in f_dict.keys():
            m_num = m_dict[key]
            f_num = f_dict[key]
            non_f_num = total_num_f - f_num
            non_m_num = total_num_m - m_num
            if f_num >= threshold and m_num >= threshold:
                # we only consider the events where there are at least {thresohld} occurences for both gender
                odds_ratio[key] = round((m_num / f_num) / (non_m_num / non_f_num), 2)
            else:
                continue
        return OrderedDict(sorted(odds_ratio.items(), key=itemgetter(1), reverse=True)[:topk]), \
            OrderedDict(sorted(odds_ratio.items(), key=itemgetter(1))[:topk])

# %% [markdown]
# ### *--------------------------------------------------------*

# %%
import pickle
import itertools
import spacy
from operator import itemgetter
from collections import Counter
import logging
from datetime import datetime
import numpy as np

# %%
df_m = extract_events(df_m)
df_f = extract_events(df_f)

# %%
(df_f['pl_ev_num'] > 0).value_counts(normalize=True)
# Out:
# False    0.678165
# True     0.321835
# Name: pl_ev_num, dtype: float64

# %%
((df_f['pl_ev_num'] == 0) | (df_f['cr_ev_num'] == 0)).value_counts(normalize=True)
# Out:
# True     0.778999
# False    0.221001
# dtype: float64

# %%
((df_m['pl_ev_num'] == 0) | (df_m['cr_ev_num'] == 0)).value_counts(normalize=True)
# Out:
# True     0.824777
# False    0.175223
# dtype: float64

# %%
(df_f['cr_ev_num'] > 0).value_counts(normalize=True)
# Out:
# False    0.583776
# True     0.416224
# Name: cr_ev_num, dtype: float64

# %%
(df_m['cr_ev_num'] > 0).value_counts(normalize=True)
# Out:
# False    0.636761
# True     0.363239
# Name: cr_ev_num, dtype: float64

# %%
(df_m['pl_ev_num'] > 0).value_counts(normalize=True)
# Out:
# False    0.733441
# True     0.266559
# Name: pl_ev_num, dtype: float64

# %%
import seaborn as sns
sns.distplot(df_f['pl_ev_num'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='pl_ev_num', ylabel='Density'>

# %%
df_f
# Out:
#       Unnamed: 0  Unnamed: 0.1                  name  \
# 0              0             0     Jody Adams (chef)
# 1              1             1          Einat Admony
# 2              2             2       Karen Akunowicz
# 3              3             3       Devin Alexander
# 4              4             4            Fatima Ali
# ...          ...           ...                   ...
# 5271        5271           925         Diana Wynyard
# 5272        5272           926         Susannah York
# 5273        5273           929         Loretta Young
# 5274        5274           931       Renée Zellweger
# 5275        5275           932  Catherine Zeta-Jones
#
#                                              name_url gender  \
# 0     https://en.wikipedia.org/wiki/Jody_Adams_(chef)      F
# 1          https://en.wikipedia.org/wiki/Einat_Admony      F
# 2       https://en.wikipedia.org/wiki/Karen_Akunowicz      F
# 3       https://en.wikipedia.org/wiki/Devin_Alexander      F
# 4            https://en.wikipedia.org/wiki/Fatima_Ali      F
# ...                                               ...    ...
# 5271                              /wiki/Diana_Wynyard      F
# 5272                              /wiki/Susannah_York      F
# 5273                              /wiki/Loretta_Young      F
# 5274                       /wiki/Ren%C3%A9e_Zellweger      F
# 5275                       /wiki/Catherine_Zeta-Jones      F
#
#                                             person_info  \
# 0     [{'section': 'Career', 'info': ['In 2011, Adam...
# 1     [{'section': 'Early life', 'info': ['Admony is...
# 2               [{'section': 'References', 'info': []}]
# 3     [{'section': 'Biography', 'info': ['In 2006, s...
# 4     [{'section': 'Early life', 'info': ["Fatima Al...
# ...                                                 ...
# 5271  [{'section': 'Life and career', 'info': ['Born...
# 5272  [{'section': 'Early life', 'info': ["York was ...
# 5273  [{'section': 'Early life', 'info': ['She was b...
# 5274  [{'section': 'Early life', 'info': ['Renée Kat...
# 5275  [{'section': 'Early life and initial stage car...
#
#                                           personal_life  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 5271  [[{'event_type': 'Life:Marry', 'triggers': [{'...
# 5272  [[{'event_type': 'Life:Marry', 'triggers': [{'...
# 5273  [[{'event_type': 'Life:Marry', 'triggers': [{'...
# 5274  [[{'event_type': 'Life:Marry', 'triggers': [{'...
# 5275  [[{'event_type': '', 'triggers': [{'event_type...
#
#                                                  career occupation  \
# 0     [[{'event_type': 'Business:Start-Org', 'trigge...      chefs
# 1     [[{'event_type': 'Business:Start-Org', 'trigge...      chefs
# 2                                                    []      chefs
# 3                                                    []      chefs
# 4     [[{'event_type': '', 'triggers': [{'event_type...      chefs
# ...                                                 ...        ...
# 5271                                                 []     acting
# 5272  [[{'event_type': '', 'triggers': [{'event_type...     acting
# 5273  [[], [{'event_type': 'Life:Marry', 'triggers':...     acting
# 5274  [[{'event_type': 'Life:Die', 'triggers': [{'ev...     acting
# 5275  [[{'event_type': '', 'triggers': [{'event_type...     acting
#
#                                               pl_events  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 5271  [{'event_type': 'Life:Marry', 'triggers': [{'e...
# 5272  [{'event_type': 'Life:Marry', 'triggers': [{'e...
# 5273  [{'event_type': 'Life:Marry', 'triggers': [{'e...
# 5274  [{'event_type': 'Life:Marry', 'triggers': [{'e...
# 5275  [{'event_type': '', 'triggers': [{'event_type'...
#
#                                             pl_ev_lemma  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 5271  [married, die, rehearse, replace, death, occur...
# 5272  [married, divorce, bear, play, evoke, support,...
# 5273  [married, marriage, marriage, married, married...
# 5274  [married, engage, obtain, meet, separate, star...
# 5275  [chronicle, report, meet, engage, married, div...
#
#                                           career_events  \
# 0     [{'event_type': 'Business:Start-Org', 'trigger...
# 1     [{'event_type': 'Business:Start-Org', 'trigger...
# 2                                                    []
# 3                                                    []
# 4     [{'event_type': '', 'triggers': [{'event_type'...
# ...                                                 ...
# 5271                                                 []
# 5272  [{'event_type': '', 'triggers': [{'event_type'...
# 5273  [{'event_type': 'Life:Marry', 'triggers': [{'e...
# 5274  [{'event_type': 'Life:Die', 'triggers': [{'eve...
# 5275  [{'event_type': '', 'triggers': [{'event_type'...
#
#                                         career_ev_lemma  pl_ev_num  cr_ev_num
# 0                     [open, open, provide, illustrate]          0          4
# 1     [open, introduce, list, appear, return, compet...          0          8
# 2                                                    []          0          0
# 3                                                    []          0          0
# 4                  [continue, begin, win, vote, finish]          0          5
# ...                                                 ...        ...        ...
# 5271                                                 []          7          0
# 5272  [play, begin, perform, agree, appear, play, fe...          8         35
# 5273  [married, marriage, marry, annul, elope, bill,...         26         28
# 5274  [kill, receive, note, applaud, play, plan, rec...         11         75
# 5275  [recount, receive, feature, relocate, read, de...         14         66
#
# [5276 rows x 15 columns]

# %%
def calculate_dict(female_array, male_array):
    counter_f_h = Counter(female_array)
    counter_m_h = Counter(male_array)
    
    # make sure there is no key lookup error
    for key in set(counter_f_h) - set(counter_m_h):
        counter_m_h[key] = 0
    for key in set(counter_m_h) - set(counter_f_h):
        counter_f_h[key] = 0

    return counter_f_h, counter_m_h

# %%
def counter_odds_career(career_evs_female, career_evs_male):
    counter_f_c, counter_m_c = calculate_dict(career_evs_female, career_evs_male)
    odds_m_c, odds_f_c = odds_ratio(counter_f_c, counter_m_c)
    return counter_f_c, counter_m_c, odds_m_c, odds_f_c

def check_keyword(array):
    return keyword in array

# %%
# there are two ways to do the chain list function: one is applicable to career
# the other is applicable to the personal life section, please choose the one based on the data
# def chain_list(array):
#     array_new = []
#     for i in array:
#         array_new.append(ast.literal_eval(i))
#     return (list(itertools.chain.from_iterable(array_new)))

# JULIE edits: commenting out this second definition of the function
# because the first one works with the data format, not the second
# this is also extremely poor programming practice

def chain_list(array):
    return list(itertools.chain.from_iterable(array))

# %%
df_f_occ["pl_ev_lemma"].values[0]
# Out:
# ['marriage', 'divorce', 'married', 'end']

# %%
new_occupations = ["writers", "acting", "comedians", "podcasters", "dancers", "artists", "chefs", "musicians"]
result_counter = {}
result_odds = {}
for new_occupation in new_occupations:
    print("occupation: ", new_occupation)
    df_m_occ, df_f_occ = df_m[df_m["occupation"] == new_occupation], df_f[df_f["occupation"] == new_occupation]
    # to make sure there are equal size of celebrities 
    thres = min(len(df_m_occ), len(df_f_occ))
    df_m_occ, df_f_occ = df_m_occ[:thres], df_f_occ[:thres]
#     pl_evs_f, pl_evs_m = chain(df_female_ev["pl_ev_lemma"]), chain(df_male_ev["pl_ev_lemma"])
    cr_evs_f = chain_list(df_f_occ["pl_ev_lemma"].to_list())
    cr_evs_m = chain_list(df_m_occ["pl_ev_lemma"].to_list())
    counter_f_c, counter_m_c, odds_m_c, odds_f_c = counter_odds_career(cr_evs_f, cr_evs_m)
    result_counter[new_occupation] = {
        "female": counter_f_c,
        "male": counter_m_c
    }
    result_odds[new_occupation] = {
        "female": odds_f_c,
        "male": odds_m_c
    }
# Out:
# occupation:  writers
# occupation:  acting
# occupation:  comedians
# occupation:  podcasters
# occupation:  dancers
# occupation:  artists
# occupation:  chefs
# occupation:  musicians

# %%
for occupation in new_occupations:
    print("occupation: ", occupation)
    # before calibration
    # "female top 10"
    print("*"*10 + "female top 10" + "*"*10)
    print(list(result_odds[occupation]["female"].keys())[:10])
    # "male top 10"
    print("*"*10 + "male top 10" + "*"*10)
    print(list(result_odds[occupation]["male"].keys())[:10])
# Out:
# occupation:  writers
# **********female top 10**********
# ['bury', 'die', 'birth', 'attend', 'war', 'grow', 'serve', 'appear', 'raise', 'begin']
# **********male top 10**********
# ['know', 'report', 'come', 'charge', 'publish', 'suffer', 'claim', 'state', 'return', 'describe']
# occupation:  acting
# **********female top 10**********
# ['pregnant', 'practice', 'wedding', 'record', 'convert', 'honor', 'battle', 'gain', 'retire', 'rap']
# **********male top 10**********
# ['accuse', 'trip', 'fly', 'assault', 'endorse', 'award', 'meeting', 'donate', 'fight', 'arrest']
# occupation:  comedians
# **********female top 10**********
# ['fall', 'open', 'diagnose', 'decide', 'birth', 'tweet', 'study', 'date', 'feel', 'turn']
# **********male top 10**********
# ['create', 'spend', 'lawsuit', 'propose', 'accord', 'arrest', 'find', 'visit', 'sell', 'admit']
# occupation:  podcasters
# **********female top 10**********
# ['date', 'describe', 'tell', 'life', 'come', 'leave', 'engage', 'live', 'work', 'start']
# **********male top 10**********
# ['play', 'bear', 'write', 'release', 'claim', 'divorce', 'birth', 'meet', 'announce', 'run']
# occupation:  dancers
# **********female top 10**********
# ['describe', 'diagnose', 'marry', 'play', 'speak', 'post', 'attend', 'expect', 'come', 'reside']
# **********male top 10**********
# ['hold', 'involve', 'award', 'run', 'serve', 'adopt', 'charge', 'suit', 'struggle', 'perform']
# occupation:  artists
# **********female top 10**********
# ['marriage', 'married', 'bear', 'die']
# **********male top 10**********
# ['die', 'bear', 'married', 'marriage']
# occupation:  chefs
# **********female top 10**********
# ['serve', 'announce', 'describe', 'bear', 'birth', 'die', 'life', 'death', 'state', 'marriage']
# **********male top 10**********
# ['lose', 'divorce', 'work', 'meet', 'speak', 'engage', 'attend', 'diagnose', 'wedding', 'write']
# occupation:  musicians
# **********female top 10**********
# ['die', 'married', 'meet', 'birth', 'marriage', 'live']
# **********male top 10**********
# ['live', 'meet', 'birth', 'marriage', 'married', 'die']

# %% [markdown]
# ## calibration step1: get <em>template sentences</em>

# %%
final = pd.read_csv("data/final_manual.csv")
templates = pd.DataFrame(final).drop_duplicates(subset=['Name', "Gender", "Occupation"])

# %%
templates.head(10)
# Out:
#                                                 Event              Name  \
# 0   {'text': 'hired', 'lemma': 'hire', 'start_toke...    Dolester Miles
# 1   {'text': 'hired', 'lemma': 'hire', 'start_toke...   Nancy Silverton
# 2   {'text': 'hired', 'lemma': 'hire', 'start_toke...    Beau MacMillan
# 3   {'text': 'hired', 'lemma': 'hire', 'start_toke...   Anthony Amoroso
# 4   {'text': 'met', 'lemma': 'meet', 'start_token'...      Debra Ponzek
# 5   {'text': 'met', 'lemma': 'meet', 'start_token'...   Ashleigh Shanti
# 6   {'text': 'met', 'lemma': 'meet', 'start_token'...    Ettore Boiardi
# 7   {'text': 'sold', 'lemma': 'sell', 'start_token...  Ida Bailey Allen
# 9   {'text': 'selling', 'lemma': 'sell', 'start_to...      Iliana Regan
# 10  {'text': 'sold', 'lemma': 'sell', 'start_token...    Peter Grunauer
#
#    Gender Occupation Keyword  \
# 0       F      chefs    hire
# 1       F      chefs    hire
# 2       M      chefs    hire
# 3       M      chefs    hire
# 4       F      chefs    meet
# 5       F      chefs    meet
# 6       M      chefs    meet
# 7       F      chefs    sell
# 9       F      chefs    sell
# 10      M      chefs    sell
#
#                                                  Text
# 0   In 1982, Frank Stitt opened Highlands Bar and ...
# 1   After Silverton returned to Los Angeles in 198...
# 2   MacMillan moved to Los Angeles to become sous ...
# 3   In 2003, Amoroso relocated to Las Vegas, Nevad...
# 4   Ponzek married fellow chef Bobby Flay in May 1...
# 5   In October 2018, Shanti met John Fleer, owner-...
# 6   In 1927, Boiardi met Maurice and Eva Weiner wh...
# 7   In 1924 Allen was food editor of the Sunday Ne...
# 9   In 2008, Regan began selling microgreens and v...
# 10  In 1979, Peter was joined by Karl Zartler, who...

# %%
# not reporting some of the occupations because of the small data size
selected_occupation = ["dancers", "comedians", "podcasters", "writers", "artists", "musicians", "chefs"]
select_templates = templates[templates["Occupation"].isin(selected_occupation)]

# %% [markdown]
# ## calibration step 2: based on the <em>template sentences</em>, swap names and get new sentences for calibration

# %%
import re 
import json

def swap_female(current_name, current_gender, text, future_name, future_gender):
    current_name = re.sub("[\(\[].*?[\)\]]", "", current_name)
    first_name = current_name.split(" ")[-1]  
    re_dict = {
        first_name: future_name,
    }
    if current_gender == "F" and future_gender == "M":
        re_dict["she"] = "he"
        re_dict["her"] = "his"
        re_dict["She"] = "He"
        re_dict["Her"] = "His"
    elif current_gender == "M" and future_gender == "F":
        re_dict["he"] = "she"
        re_dict["his"] = "her"
        re_dict["him"] = "her"
        re_dict["He"] = "She"
        re_dict["His"] = "Her"
        
#     print(re_dict) # JULIE edits: disable printing -- takes too long
 
    new_tokens = []
    for token in sp(text):
        if token.text in re_dict.keys():
            new_tokens.append(re_dict[token.text])
        else:
            new_tokens.append(token.text)
    replaced_string = " ".join(ele for ele in new_tokens)
    return replaced_string

# %%
# for single events, do event detection
# JULIE edits: modify path name
name_list = json.loads(open("data/names.json", "rb").readlines()[0])

# fifty sample names
sample_name = 50
male_names = name_list["men"][:50]
female_names = name_list["women"][:50]

# %%
gen_sen = []
for i, row in select_templates.iterrows():
    original_text = row["Text"]
    cur_gender = row["Gender"]
    cur_name = row["Name"]
    f_gens = ["M", "F"]
    for f_gen in f_gens:
        if f_gen == "M":
            for name in male_names:
                future_text =  swap_female(cur_name, cur_gender, original_text, name, f_gen)
                gen_sen.append({
                    "Event":row["Event"],
                    "Name": name,
                    "Gender": f_gen,
                    "Occupation": row["Occupation"],
                    "Keyword": row["Keyword"],
                    "Text": future_text
                })
        if f_gen == "F":
            for name in female_names:
                future_text =  swap_female(cur_name, cur_gender, original_text, name, f_gen)
                gen_sen.append({
                    "Event":row["Event"],
                    "Name": name,
                    "Gender": f_gen,
                    "Occupation": row["Occupation"],
                    "Keyword": row["Keyword"],
                    "Text": future_text
                })

# %%
import pickle
import pandas as pd

# read the result
result_list = []
for occupation in new_occupations:
    # to get this, you will need to run the event extraction model from Han et. al 2019.
    # JULIE edits: change path
    df = pickle.load(open(f"data/ee-model/res_{occupation}.p", "rb"))
    result = {}
    for key, group in df.groupby(["Gender", "Keyword"]):
        if group["Result"].unique().tolist() == [False]:
            # for the case where target events in all templates all did not get detected
            # then do not calibrate this event and directly use the original occurence
            print(f"not calibrating event {key[1]} for gender {key[0]}?")
            print("Example: ", group["Text"].tolist()[0])
        event = key[1]
        gender = key[0]
        if event not in result:
            print(f"adding event {event}")
            result[event] = {}
        percent = sum(group["Result"].tolist()) / len(group["Result"].tolist())
        result[event][gender] = percent
    result_list.append(result)
# Out:
# adding event appear
# adding event attend
# adding event begin
# adding event birth
# adding event bury
# adding event charge
# adding event claim
# adding event come
# adding event describe
# adding event die
# adding event grow
# adding event know
# adding event publish
# adding event raise
# adding event report
# adding event return
# adding event serve
# adding event state
# adding event suffer
# not calibrating event war for gender F?
# Example:  Lucy Jennifer was the daughter of Colonel William Houston and Cornelia Humes Graham Jennifer . Her grandfather was Major General Robert Jennifer , who served in the War of 1812 , the Mexican – American War , and the Civil War.[4 ]
#
# adding event war
# not calibrating event war for gender M?
# Example:  Lucy Michael was the daughter of Colonel William Houston and Cornelia Humes Graham Michael . His grandfather was Major General Robert Michael , who served in the War of 1812 , the Mexican – American War , and the Civil War.[4 ]
#
# adding event accuse
# adding event arrest
# adding event assault
# adding event award
# adding event battle
# adding event convert
# adding event donate
# adding event endorse
# adding event fight
# adding event fly
# adding event gain
# adding event honor
# adding event meeting
# adding event practice
# adding event pregnant
# not calibrating event rap for gender F?
# Example:  Jennifer has been married three times . She first married Louie Ritter in 1953 , but the marriage ended within a year , after which she enrolled at the Actors Studio in New York City.[85 ] Jennifer alleged that Ritter had raped her when she was still a virgin in the early stages of their relationship.[40 ] Her second was to director Jack Garfein , a Holocaust survivor she met at the Studio and for whom she converted to Judaism ( having been raised a Catholic).[86 ] They had one daughter , Blanche Jennifer ( born 1956),[87 ] also an actress , and a son , Herschel Garfein ( born 1958),[88 ] who is a composer and faculty member at the Steinhardt School of Music at New York University . Garfein and Jennifer divorced in 1969 . Jennifer also has six grandchildren .
#
# adding event rap
# adding event record
# adding event retire
# not calibrating event trip for gender F?
# Example:  Jennifer also advocates breastfeeding . During a UNICEF fact - finding trip to Sierra Leone , she breastfed a hungry week - old baby whose mother could not produce milk.[73 ] She said she did it to reduce the stigma associated with breastfeeding and to encourage infant nutrition.[74 ]
#
# adding event trip
# not calibrating event wedding for gender F?
# Example:  Hours before her death , Jennifer married long - time companion Gerry DeFord , with whom she had lived for 19 years . Though Jennifer ' daughter objected to the marriage , the actress Sally Kirkland performed the wedding ceremony for the two at Jennifer ' deathbed . Kirkland , a minister of the Movement of Spiritual Inner Awareness , also performed non - denominational last rites for Jennifer .
#
# adding event wedding
# not calibrating event rap for gender M?
# Example:  Michael has been married three times . He first married Louie Ritter in 1953 , but the marriage ended within a year , after which he enrolled at the Actors Studio in New York City.[85 ] Michael alleged that Ritter had raped his when he was still a virgin in the early stages of their relationship.[40 ] His second was to director Jack Garfein , a Holocaust survivor he met at the Studio and for whom he converted to Judaism ( having been raised a Catholic).[86 ] They had one daughter , Blanche Michael ( born 1956),[87 ] also an actress , and a son , Herschel Garfein ( born 1958),[88 ] who is a composer and faculty member at the Steinhardt School of Music at New York University . Garfein and Michael divorced in 1969 . Michael also has six grandchildren .
#
# not calibrating event trip for gender M?
# Example:  Michael also advocates breastfeeding . During a UNICEF fact - finding trip to Sierra Leone , he breastfed a hungry week - old baby whose mother could not produce milk.[73 ] He said he did it to reduce the stigma associated with breastfeeding and to encourage infant nutrition.[74 ]
#
# not calibrating event wedding for gender M?
# Example:  Hours before his death , Michael married long - time companion Gerry DeFord , with whom he had lived for 19 years . Though Michael ' daughter objected to the marriage , the actress Sally Kirkland performed the wedding ceremony for the two at Michael ' deathbed . Kirkland , a minister of the Movement of Spiritual Inner Awareness , also performed non - denominational last rites for Michael .
#
# adding event accord
# adding event admit
# adding event arrest
# adding event birth
# adding event create
# adding event date
# adding event decide
# adding event diagnose
# adding event fall
# adding event feel
# adding event find
# not calibrating event lawsuit for gender F?
# Example:  After being fired by Roseanne , Geraldine filed a $ 70.3 million breach of contract lawsuit in Superior Court of Los Angeles County on December 18 , 1991 . She said Jennifer promised her half the earnings from the Roseanne show for helping invent the " domestic goddess " character in 1981 , serving as " writer , organizer , accountant , bookkeeper and confidante".[62 ] Since it was six months past the statute of limitations , the suit was thrown out.[61 ]
#
# adding event lawsuit
# adding event open
# adding event propose
# adding event sell
# adding event spend
# adding event study
# adding event turn
# adding event tweet
# adding event visit
# not calibrating event lawsuit for gender M?
# Example:  After being fired by Roseanne , Geraldine filed a $ 70.3 million breach of contract lawsuit in Superior Court of Los Angeles County on December 18 , 1991 . He said Michael promised his half the earnings from the Roseanne show for helping invent the " domestic goddess " character in 1981 , serving as " writer , organizer , accountant , bookkeeper and confidante".[62 ] Since it was six months past the statute of limitations , the suit was thrown out.[61 ]
#
# adding event announce
# adding event bear
# adding event birth
# adding event claim
# adding event come
# adding event date
# adding event describe
# adding event divorce
# adding event engage
# adding event leave
# adding event life
# adding event live
# adding event meet
# adding event play
# adding event release
# adding event run
# adding event start
# adding event tell
# adding event work
# adding event write
# not calibrating event run for gender M?
# Example:  Wolf is married to film director Bethany Ashton Wolf.[9][16 ] His cousin is former Party of Five actor Scott Wolf.[17 ]
#  On an episode of The Church of What 's Happening Now with Joey Diaz , Josh detailed a true story about a food truck - style business he once ran called PB&J'S.
#  He was ordered to shut down after an inspector found Josh and his children making peanut butter and jelly sandwiches on an apartment floor.[18 ] Josh Wolf is an alumnus of Trinity University in San Antonio , Texas.[19 ]
#
# adding event adopt
# adding event attend
# adding event award
# adding event charge
# adding event come
# adding event describe
# adding event diagnose
# adding event expect
# adding event hold
# adding event involve
# adding event marry
# adding event perform
# adding event play
# adding event post
# adding event reside
# adding event run
# adding event serve
# adding event speak
# adding event struggle
# not calibrating event suit for gender F?
# Example:  Jennifer admitted in court documents that she had lied about her age . In May 1997 , she filed suit in Cook County seeking to have all records of the marriage expunged because she was not old enough under state law to get married without her parents ' consent . It was reported that she cut off all professional and personal ties with Kelly after the marriage was annulled and ceased having contact with him.[145 ] In 2014 , Jomo Hankerson stated that Jennifer " got villainized " over her relationship with Kelly and the scandal over the marriage made it difficult to find producers for her second album . " We were coming off of a multi - platinum debut album and except for a couple of relationships with Jermaine Dupri and Puffy , it was hard for us to get producers on the album . " Hankerson also expressed confusion over why " they were upset " with Jennifer given her age at the time.[146 ]
#
# adding event suit
# not calibrating event marry for gender M?
# Example:  Throughout the late 1920s and early 1930s , Michael continued his on - again , off - again relationship with George Preston Marshall which he later described as abusive.[99 ]   Marshall was purportedly " his frequent bedfellow and constant adviser[e ] between 1927 and 1933."[34][99 ] Marshall repeatedly asked his to marry him but , after learning that he had had many affairs while they were together and believing his to be incapable of fidelity , he married film actress Corinne Griffith instead.[99 ]
#
# not calibrating event suit for gender M?
# Example:  Michael admitted in court documents that he had lied about his age . In May 1997 , he filed suit in Cook County seeking to have all records of the marriage expunged because he was not old enough under state law to get married without his parents ' consent . It was reported that he cut off all professional and personal ties with Kelly after the marriage was annulled and ceased having contact with him.[145 ] In 2014 , Jomo Hankerson stated that Michael " got villainized " over his relationship with Kelly and the scandal over the marriage made it difficult to find producers for his second album . " We were coming off of a multi - platinum debut album and except for a couple of relationships with Jermaine Dupri and Puffy , it was hard for us to get producers on the album . " Hankerson also expressed confusion over why " they were upset " with Michael given his age at the time.[146 ]
#
# adding event bear
# adding event die
# not calibrating event marriage for gender F?
# Example:  The Jennifer home after their marriage was in Portland.[3 ]
#
# adding event marriage
# adding event married
# not calibrating event marriage for gender M?
# Example:  The Michael home after their marriage was in Portland.[3 ]
#
# adding event announce
# not calibrating event attend for gender F?
# Example:  Jennifer was born to Japanese parents in Koreatown in Los Angeles . Her parents worked as fish distributors ( now run by her older brother ) and ended up divorcing when Jennifer was 12.[2 ] She later attended culinary school in Pasadena , after which she worked at Mori Sushi . " Committed to exploring new techniques , " she then began a three - year working tour of Japan , where she immersed herself as much as possible " in the essentials of Japanese cuisine."[3 ] While there , she cooked at Shirakawa - Ya Ryokan under Chef Masa Sato , a Japanese country - style inn owned by her cousins that was renowned for its kaiseki cuisine.[3 ] Her experiences with Japanese cuisine deeply influenced her , and upon returning to California , opened Azami Sushi Cafe ( known for its all female staff ) with the stressful help of her family.[3 ] Ultimately , she opened her now famous n / naka restaurant in Los Angeles , where she works with her wife , Carole Iida , who is a partner and sous chef at n / naka.[4 ] Jennifer and Iida reside in Arcadia , California.[2 ]
#
# adding event attend
# adding event bear
# adding event birth
# adding event death
# adding event describe
# adding event diagnose
# adding event die
# adding event divorce
# adding event engage
# adding event life
# adding event lose
# not calibrating event marriage for gender F?
# Example:  Jennifer married twice and although she had no biological children , she was stepmother to Dana Gasby . Her first marriage was to former HBO executive Donald " Don " Anderson from 1986 until 1990.[25 ] Jennifer began dating Anderson after formally meeting him at her restaurant in late 1986.[11 ] Jennifer married Dan Gasby in 1992 at St. Luke 's Lutheran Church in Manhattan . Gasby was the executive producer of the Essence Awards and the senior vice president of marketing at Camelot Entertainment Sales Inc.[2][26][27 ] Jennifer was stepmother of Gasby 's daughter , Dana.[28 ]
#
# adding event marriage
# adding event meet
# adding event serve
# adding event speak
# adding event state
# not calibrating event wedding for gender F?
# Example:  Jennifer is married to the model Gate ( Maya ) Haile . Their wedding was in Addis Ababa , Ethiopia.[35 ] They reside in Harlem , New York , New York , near the site of her restaurant , Red Rooster.[8][36 ]   They welcomed their son , Zion Mandela , on 19 July 2016 .   Jennifer has an adult daughter , Zoe.[37 ]
#
# adding event wedding
# adding event work
# adding event write
# not calibrating event attend for gender M?
# Example:  Michael was born to Japanese parents in Koreatown in Los Angeles . His parents worked as fish distributors ( now run by his older brother ) and ended up divorcing when Michael was 12.[2 ] He later attended culinary school in Pasadena , after which he worked at Mori Sushi . " Committed to exploring new techniques , " he then began a three - year working tour of Japan , where he immersed herself as much as possible " in the essentials of Japanese cuisine."[3 ] While there , he cooked at Shirakawa - Ya Ryokan under Chef Masa Sato , a Japanese country - style inn owned by his cousins that was renowned for its kaiseki cuisine.[3 ] His experiences with Japanese cuisine deeply influenced his , and upon returning to California , opened Azami Sushi Cafe ( known for its all female staff ) with the stressful help of his family.[3 ] Ultimately , he opened his now famous n / naka restaurant in Los Angeles , where he works with his wife , Carole Iida , who is a partner and sous chef at n / naka.[4 ] Michael and Iida reside in Arcadia , California.[2 ]
#
# not calibrating event marriage for gender M?
# Example:  Michael married twice and although he had no biological children , he was stepmother to Dana Gasby . His first marriage was to former HBO executive Donald " Don " Anderson from 1986 until 1990.[25 ] Michael began dating Anderson after formally meeting him at his restaurant in late 1986.[11 ] Michael married Dan Gasby in 1992 at St. Luke 's Lutheran Church in Manhattan . Gasby was the executive producer of the Essence Awards and the senior vice president of marketing at Camelot Entertainment Sales Inc.[2][26][27 ] Michael was stepmother of Gasby 's daughter , Dana.[28 ]
#
# not calibrating event wedding for gender M?
# Example:  Michael is married to the model Gate ( Maya ) Haile . Their wedding was in Addis Ababa , Ethiopia.[35 ] They reside in Harlem , New York , New York , near the site of his restaurant , Red Rooster.[8][36 ]   They welcomed their son , Zion Mandela , on 19 July 2016 .   Michael has an adult daughter , Zoe.[37 ]
#
# not calibrating event birth for gender F?
# Example:  In 1985 , Jennifer stopped composing and recording music after moving to San Diego , California , where she married and gave birth to a son , and took up the practice of transcendental meditation.[2 ] Under the name Joanne ( with an " e " ) Jennifer , she became a prolific writer of historical fiction and plays , as well as a notable producer of Internet content.[4 ] She died on April 28 , 2017 , at the age of 68.[7 ]
#
# adding event birth
# adding event die
# adding event live
# not calibrating event marriage for gender F?
# Example:  Soon after her marriage to Jennifer , she lived at 1386 West 13th St. , Los Angeles , and then at 4074 Bluff Place , San Pedro , California . She later moved to 657 6th Street , San Pedro.[1][10][20 ]
#
# adding event marriage
# adding event married
# adding event meet
# not calibrating event birth for gender M?
# Example:  In 1985 , Michael stopped composing and recording music after moving to San Diego , California , where he married and gave birth to a son , and took up the practice of transcendental meditation.[2 ] Under the name Joanne ( with an " e " ) Michael , he became a prolific writer of historical fiction and plays , as well as a notable producer of Internet content.[4 ] He died on April 28 , 2017 , at the age of 68.[7 ]
#
# not calibrating event marriage for gender M?
# Example:  Soon after his marriage to Michael , he lived at 1386 West 13th St. , Los Angeles , and then at 4074 Bluff Place , San Pedro , California . He later moved to 657 6th Street , San Pedro.[1][10][20 ]

# %% [markdown]
# ## calculate the odds ratio again after getting the calibration result

# %%
cali_result = {}
for i in range(0, len(new_occupations)):
    curr_occu = new_occupations[i]
    if curr_occu not in cali_result:
        cali_result[curr_occu] = {
            "F": {},
            "M": {}
        }
    cali_dict = result_list[i]
    prev_counter_f = result_counter[new_occupations[i]]["female"]
    for f_key in prev_counter_f.keys():
        if f_key in cali_dict:
            if "F" in cali_dict[f_key]:
                percent = cali_dict[f_key]["F"]
                if percent != 0:
                    new_count = prev_counter_f[f_key] / percent
                else:
                    new_count = prev_counter_f[f_key] 
                cali_result[curr_occu]["F"][f_key] = new_count
            else:
                cali_result[curr_occu]["F"][f_key] = prev_counter_f[f_key]
        else:
            cali_result[curr_occu]["F"][f_key] = prev_counter_f[f_key]
                
    prev_counter_m = result_counter[new_occupations[i]]["male"]
    for m_key in prev_counter_m.keys():
        if m_key in cali_dict:
            if "M" in cali_dict[m_key]:
                percent = cali_dict[m_key]["M"]
                if percent != 0:
                    new_count = prev_counter_m[m_key] / percent
                else:
                    new_count = prev_counter_m[m_key] 
                cali_result[curr_occu]["M"][m_key] = new_count
            else:
                cali_result[curr_occu]["M"][m_key] = prev_counter_m[m_key]  
        else:
            cali_result[curr_occu]["M"][m_key] = prev_counter_m[m_key]

# %% [markdown]
# ## get the final result that is reported in the paper
# ### also plot the bartchart of the calibration result

# %%
import seaborn as sns
import operator
import matplotlib.pyplot as plt
for occu in new_occupations:
    print("Occupation: ", occu)
    m_dict_occu, f_dict_occu = odds_ratio(cali_result[occu]["F"], cali_result[occu]["M"])
    print("male: ", list(m_dict_occu.keys())[:10])
    print("female: ", list(f_dict_occu.keys())[:10])
    female_events = list(f_dict_occu.keys())[:5]
    male_events = list(m_dict_occu.keys())[:5]
    
    sorted_counter_f_pl = {k: v for k, v in sorted(cali_result[occu]["F"].items(), key=lambda item: item[1], reverse=True)}
    sorted_counter_m_pl = {k: v for k, v in sorted(cali_result[occu]["M"].items(), key=lambda item: item[1], reverse=True)}
    m_topic_pl = list(sorted_counter_m_pl.keys())
    f_topic_pl = list(sorted_counter_f_pl.keys())
    for gender in ["F", "M"]:
        position = []
        if gender == "F":
            select_events = female_events
        else:
            select_events = male_events
        
        for m_topic in select_events:
            position.append({
                "percent": m_topic_pl.index(m_topic) / len(m_topic_pl) * 100,
                "gender": "male",
                "event": m_topic
                })
            position.append({
                "percent": f_topic_pl.index(m_topic) / len(m_topic_pl) * 100,
                "gender": "female",
                "event": m_topic
                })

        df = pd.DataFrame(position)
        g = sns.catplot(x='event', y='percent', hue='gender', data=df, kind='bar', palette = sns.color_palette("pastel"))
        g.set_xticklabels(fontsize = 15, rotation=30)
        g.set_yticklabels(fontsize = 15)
        g.despine(left=True)    
        # JULIE edits: don't need to save, just display
        
#         g.savefig(f"pl_figs/{occu}_{gender}.pdf", dpi=1000)
plt.show()
# Out:
# Occupation:  writers
# male:  ['know', 'report', 'come', 'charge', 'publish', 'claim', 'suffer', 'return', 'state', 'describe']
# female:  ['bury', 'birth', 'attend', 'war', 'grow', 'serve', 'appear', 'raise', 'begin', 'divorce']
# Occupation:  acting
# male:  ['accuse', 'trip', 'fly', 'assault', 'endorse', 'meeting', 'donate', 'fight', 'arrest', 'found']
# female:  ['pregnant', 'practice', 'wedding', 'record', 'convert', 'honor', 'gain', 'retire', 'rap', 'bring']
# Occupation:  comedians
# male:  ['visit', 'create', 'spend', 'propose', 'lawsuit', 'accord', 'arrest', 'find', 'sell', 'admit']
# female:  ['feel', 'birth', 'fall', 'open', 'decide', 'date', 'diagnose', 'tweet', 'study', 'turn']
# Occupation:  podcasters
# male:  ['play', 'write', 'bear', 'release', 'claim', 'birth', 'divorce', 'meet', 'announce', 'work']
# female:  ['date', 'describe', 'tell', 'life', 'come', 'leave', 'engage', 'live', 'start', 'reside']
# Occupation:  dancers
# male:  ['hold', 'involve', 'award', 'run', 'serve', 'adopt', 'charge', 'suit', 'struggle', 'perform']
# female:  ['marry', 'describe', 'diagnose', 'expect', 'speak', 'post', 'attend', 'come', 'play', 'reside']
# Occupation:  artists
# male:  ['die', 'bear', 'married', 'marriage']
# female:  ['marriage', 'married', 'bear', 'die']
# Occupation:  chefs
# male:  ['birth', 'lose', 'divorce', 'speak', 'meet', 'work', 'diagnose', 'wedding', 'write', 'engage']
# female:  ['death', 'serve', 'announce', 'describe', 'bear', 'die', 'life', 'state', 'marriage', 'live']
# Occupation:  musicians
# male:  ['live', 'meet', 'birth', 'marriage', 'married', 'die']
# female:  ['die', 'married', 'meet', 'birth', 'marriage', 'live']

# %%
events='''Occupation:  writers
male:  ['know', 'report', 'come', 'charge', 'publish', 'claim', 'suffer', 'return', 'state', 'describe']
female:  ['bury', 'birth', 'attend', 'war', 'grow', 'serve', 'appear', 'raise', 'begin', 'divorce']
Occupation:  acting
male:  ['accuse', 'trip', 'fly', 'assault', 'endorse', 'meeting', 'donate', 'fight', 'arrest', 'found']
female:  ['pregnant', 'practice', 'wedding', 'record', 'convert', 'honor', 'gain', 'retire', 'rap', 'bring']
Occupation:  comedians
male:  ['visit', 'create', 'spend', 'propose', 'lawsuit', 'accord', 'arrest', 'find', 'sell', 'admit']
female:  ['feel', 'birth', 'fall', 'open', 'decide', 'date', 'diagnose', 'tweet', 'study', 'turn']
Occupation:  podcasters
male:  ['play', 'write', 'bear', 'release', 'claim', 'birth', 'divorce', 'meet', 'announce', 'work']
female:  ['date', 'describe', 'tell', 'life', 'come', 'leave', 'engage', 'live', 'start', 'reside']
Occupation:  dancers
male:  ['hold', 'involve', 'award', 'run', 'serve', 'adopt', 'charge', 'suit', 'struggle', 'perform']
female:  ['marry', 'describe', 'diagnose', 'expect', 'speak', 'post', 'attend', 'come', 'play', 'reside']
Occupation:  artists
male:  ['die', 'bear', 'married', 'marriage']
female:  ['marriage', 'married', 'bear', 'die']
Occupation:  chefs
male:  ['birth', 'lose', 'divorce', 'speak', 'meet', 'work', 'diagnose', 'wedding', 'write', 'engage']
female:  ['death', 'serve', 'announce', 'describe', 'bear', 'die', 'life', 'state', 'marriage', 'live']
Occupation:  musicians
male:  ['live', 'meet', 'birth', 'marriage', 'married', 'die']
female:  ['die', 'married', 'meet', 'birth', 'marriage', 'live']'''

# %%
import ast
occu_gender_events = {}
for line in events.split('\n'):
    if line.startswith('Occupation'):
        occu = line[len('Occupation:  '):]
    if line.startswith('male'):
        evs = ast.literal_eval(line[len('male:  '):])
        occu_gender_events[(occu, 'male')] = evs
    elif line.startswith('female'):
        evs = ast.literal_eval(line[len('female:  '):])
        occu_gender_events[(occu, 'female')] = evs
occu_gender_events
# Out:
# {('writers', 'male'): ['know',
#   'report',
#   'come',
#   'charge',
#   'publish',
#   'claim',
#   'suffer',
#   'return',
#   'state',
#   'describe'],
#  ('writers', 'female'): ['bury',
#   'birth',
#   'attend',
#   'war',
#   'grow',
#   'serve',
#   'appear',
#   'raise',
#   'begin',
#   'divorce'],
#  ('acting', 'male'): ['accuse',
#   'trip',
#   'fly',
#   'assault',
#   'endorse',
#   'meeting',
#   'donate',
#   'fight',
#   'arrest',
#   'found'],
#  ('acting', 'female'): ['pregnant',
#   'practice',
#   'wedding',
#   'record',
#   'convert',
#   'honor',
#   'gain',
#   'retire',
#   'rap',
#   'bring'],
#  ('comedians', 'male'): ['visit',
#   'create',
#   'spend',
#   'propose',
#   'lawsuit',
#   'accord',
#   'arrest',
#   'find',
#   'sell',
#   'admit'],
#  ('comedians', 'female'): ['feel',
#   'birth',
#   'fall',
#   'open',
#   'decide',
#   'date',
#   'diagnose',
#   'tweet',
#   'study',
#   'turn'],
#  ('podcasters', 'male'): ['play',
#   'write',
#   'bear',
#   'release',
#   'claim',
#   'birth',
#   'divorce',
#   'meet',
#   'announce',
#   'work'],
#  ('podcasters', 'female'): ['date',
#   'describe',
#   'tell',
#   'life',
#   'come',
#   'leave',
#   'engage',
#   'live',
#   'start',
#   'reside'],
#  ('dancers', 'male'): ['hold',
#   'involve',
#   'award',
#   'run',
#   'serve',
#   'adopt',
#   'charge',
#   'suit',
#   'struggle',
#   'perform'],
#  ('dancers', 'female'): ['marry',
#   'describe',
#   'diagnose',
#   'expect',
#   'speak',
#   'post',
#   'attend',
#   'come',
#   'play',
#   'reside'],
#  ('artists', 'male'): ['die', 'bear', 'married', 'marriage'],
#  ('artists', 'female'): ['marriage', 'married', 'bear', 'die'],
#  ('chefs', 'male'): ['birth',
#   'lose',
#   'divorce',
#   'speak',
#   'meet',
#   'work',
#   'diagnose',
#   'wedding',
#   'write',
#   'engage'],
#  ('chefs', 'female'): ['death',
#   'serve',
#   'announce',
#   'describe',
#   'bear',
#   'die',
#   'life',
#   'state',
#   'marriage',
#   'live'],
#  ('musicians', 'male'): ['live',
#   'meet',
#   'birth',
#   'marriage',
#   'married',
#   'die'],
#  ('musicians', 'female'): ['die',
#   'married',
#   'meet',
#   'birth',
#   'marriage',
#   'live']}

# %%
new_occupations = ["writers", "acting", "comedians", "podcasters", "dancers",  "chefs"]
for occu in new_occupations:
    print(occu.capitalize(), '& F & &  ', ', '.join(occu_gender_events[(occu, 'female')][:5]), '\\\\')
    print('       & M & & ', ', '.join(occu_gender_events[(occu, 'male')][:5]), '\\\\')
# Out:
# Writers & F & &   bury, birth, attend, war, grow \\
#        & M & &  know, report, come, charge, publish \\
# Acting & F & &   pregnant, practice, wedding, record, convert \\
#        & M & &  accuse, trip, fly, assault, endorse \\
# Comedians & F & &   feel, birth, fall, open, decide \\
#        & M & &  visit, create, spend, propose, lawsuit \\
# Podcasters & F & &   date, describe, tell, life, come \\
#        & M & &  play, write, bear, release, claim \\
# Dancers & F & &   marry, describe, diagnose, expect, speak \\
#        & M & &  hold, involve, award, run, serve \\
# Chefs & F & &   death, serve, announce, describe, bear \\
#        & M & &  birth, lose, divorce, speak, meet \\

# %%
pocaster male bear

# %%
from WEAT.weat import run_test, load_embedding

# %%
glove_embeddings = load_embedding('WEAT/embeddings/glove.840B.300d.processed.txt')
w2v_embeddings = load_embedding('WEAT/embeddings/GoogleNews-vectors-negative300.bin')
# Out:
# WEAT/embeddings/glove.840B.300d.processed.txt
# WEAT/embeddings/GoogleNews-vectors-negative300.bin

# %%
new_occupations = ["writers", "acting", "comedians", "podcasters", "dancers", "artists", "chefs", "musicians"]
config = {}
config['A'] = ["male", "man", "boy", "brother", "he", "him", "his", "son", "father", "uncle", "grandfather"]
config['B'] = ["female", "woman", "girl", "sister", "she", "her", "hers", "daughter", "mother", "aunt", "grandmother"]

for occu in new_occupations:
    config['X'] = occu_gender_events[(occu, 'male')]
    config['Y'] = occu_gender_events[(occu, 'female')]
    glove_weat = run_test(config, glove_embeddings)
    w2v_weat = run_test(config, w2v_embeddings)
    print(f'{occu} glove {glove_weat[0]:.2f} w2v {w2v_weat[0]:.2f}')
# Out:
# writers glove 0.41 w2v 0.60
# acting glove 0.09 w2v -0.15
# comedians glove 0.52 w2v 0.22
# podcasters glove 0.08 w2v -0.00
# dancers glove 0.29 w2v 0.11
# artists glove -0.18 w2v -0.02
# chefs glove -0.77 w2v -0.12
# musicians glove 0.08 w2v -0.18

# %%
new_occupations = ["writers", "acting", "comedians", "podcasters", "dancers", "artists", "chefs", "musicians"]
config = {}
config['A'] = ["male", "man", "boy", "brother", "he", "him", "his", "son", "father", "uncle", "grandfather"]
config['B'] = ["female", "woman", "girl", "sister", "she", "her", "hers", "daughter", "mother", "aunt", "grandmother"]

for occu in new_occupations:
    config['X'] = occu_gender_events[(occu, 'male')][:5]
    config['Y'] = occu_gender_events[(occu, 'female')][:5]
    glove_weat = run_test(config, glove_embeddings)
    w2v_weat = run_test(config, w2v_embeddings)
    print(f'{occu} glove {glove_weat[0]:.2f} w2v {w2v_weat[0]:.2f}')
# Out:
# writers glove 0.24 w2v 0.48
# acting glove 0.51 w2v 0.12
# comedians glove -0.09 w2v -0.39
# podcasters glove 0.45 w2v 0.42
# dancers glove 0.55 w2v 0.34
# artists glove 0.11 w2v -0.13
# chefs glove -0.93 w2v -0.68
# musicians glove -0.20 w2v -0.30
